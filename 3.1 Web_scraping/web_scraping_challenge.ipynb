# %% [markdown]
# <h3>Web Scraping Challenge: Scraping News Headlines and Summaries</h3>
# <strong>Website:</strong> Example News Site (Replace with an actual news site for practice)
#
# <strong>Instructions:</strong>
# <ol>
#  	<li><strong>Objective:</strong>
# <ul>
#  	<li>Extract the headlines and summaries of the latest news articles.</li>
# </ul>
# </li>
#  	<li><strong>Steps:</strong>
# <ul>
#  	<li>Install Beautiful Soup and requests libraries.</li>
#  	<li>Fetch the HTML content of the news homepage.</li>
#  	<li>Parse the HTML content to find the elements containing news headlines and summaries.</li>
#  	<li>Print the headlines and summaries.</li>
# </ul>
# </li>
#  	<li><strong>Submission:</strong>
# <ul>
#  	<li>
# <div id="tutor-page-wrap" class="tutor-site-wrap site">
# <div class="tutor-course-single-content-wrapper tutor-spotlight-mode">
# <div id="tutor-single-entry-content" class="tutor-quiz-single-entry-wrap">
# <div class="tutor-course-topic-single-body">
# <div class="tutor-course-spotlight-wrapper">
# <div class="tutor-tab tutor-course-spotlight-tab">
# <div id="tutor-course-spotlight-overview" class="tutor-tab-item is-active">
# <div class="tutor-container">
# <div class="tutor-row tutor-justify-center">
# <div class="tutor-col-xl-8">
# <div class="tutor-fs-6 tutor-color-secondary tutor-lesson-wrapper">
# <p dir="auto">Submit your code as a GitHub repository to your group with your technical mentor, and include a README file with instructions on how to set up and run the app.</p>
#
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div id="wpadminbar" class="nojq"></div></li>
# </ul>
# </li>
# </ol>
